# %%
import pandas as pd 

df = pd.read_csv("C:\\Users\\Dell\\Documents\\python\\Githup\\Boda1515\\Amazon_project\\phones-data\\Phones_Page_30_50.csv")

df
# Out:
#                                                  Title           Rate Price  \
# 0    جراب متوافق مع Vivo V29e 5G ، - غطاء حماية مصق...  Previous page   299
# 1    جراب متوافق مع ريلمى 7 برو ، - غطاء حماية مصقو...  Previous page   329
# 2    جراب متوافق مع وان بلس Ace 3 5G ، - غطاء حماية...  Previous page   369
# 3    جراب متوافق مع Oppo Find X5 ، - غطاء حماية مصق...  Previous page   369
# 4    جراب متوافق مع شاومى Poco F4 GT ، - غطاء حماية...  Previous page   359
# ..                                                 ...            ...   ...
# 432  جراب متوافق مع شاومى Poco M6 Pro 4G ، - غطاء ح...  Previous page   309
# 433  جراب متوافق مع شاومى Redmi Note 13 Pro 4G ، - ...  Previous page   309
# 434  جراب متوافق مع Oppo Reno 7 5G (International) ...  Previous page   284
# 435  جراب متوافق مع Oppo F9 ، - غطاء حماية مصقول مق...  Previous page   199
# 436  جراب متوافق مع Oppo Find X5 Pro ، - غطاء حماية...  Previous page   329
#
#     Price Before Discount Discount  \
# ...
